# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
import os
print(os.getcwd())

# %%
import os

for file in os.listdir():
    print(file)

# %%
import os

for file in os.listdir():
    print(file)

# %%
import pynvml

pynvml.nvmlInit()

handle = pynvml.nvmlDeviceGetHandleByIndex(0)

power = pynvml.nvmlDeviceGetPowerUsage(handle)

print("Current Power:", power/1000, "W")

pynvml.nvmlShutdown()
# Out:
# Current Power: 16.505 W

# %%
# !pip install nvidia-ml-py

# %%
# !nvidia-smi
# Out:
# Fri Jun 26 12:40:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.07                 Driver Version: 566.07         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   61C    P0             16W /   75W |    1276MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !python validate_figure1.py --duration 60 --interval 0.05
# Out:
# Using device: NVIDIA GeForce RTX 3050 Laptop GPU
#
# Measuring idle GPU power baseline (3s)...
#   Idle power: 16.90 W
#
# [1/2] Running custom Transformer (1 enc / 1 dec layer, 8 heads, d_model=512, seq_len=200, decode_len=200, batch=64) for 60.0s ...
#   Samples collected: 1273
#   Mean power - Encoder phase: 69.25 W (delta vs idle: +52.35 W)
#   Mean power - Decoder phase: 74.10 W (delta vs idle: +57.20 W)
#   Decoder - Encoder delta: +4.85 W (paper reports decoder >> encoder, e.g. ~20W vs ~2W)
#
# [2/2] Running CNN model for 60.0s ...
#   Samples collected: 1186
#   CNN mean power: 72.47 W, std: 3.37 W (paper reports a steady ~constant trace)
#
# Saved plot to figure1_validation.png
# Figure(1200x400)
# C:\Users\ANIKET\anaconda3\Lib\site-packages\torch\nn\modules\transformer.py:144: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
# ...

# %%
import os

print(os.path.exists("figure1_validation.png"))
# Out:
# True

# %%
from PIL import Image
from IPython.display import display

display(Image.open("figure1_validation.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x600>

# %%
# !python validate_figure1.py --duration 60
# Out:
# Using device: NVIDIA GeForce RTX 3050 Laptop GPU
#
# Measuring idle GPU power baseline (3s)...
#   Idle power: 16.05 W
#
# [1/2] Running custom Transformer (1 enc / 1 dec layer, 8 heads, d_model=512, seq_len=512, decode_len=512, batch=128) for 60.0s ...
# Encoder duration: 41313.45 ms
# Decoder duration: 633906.78 ms
#   Samples collected: 119526
#   Mean power - Encoder phase: 54.90 W (delta vs idle: +38.85 W)
#   Mean power - Decoder phase: 56.73 W (delta vs idle: +40.68 W)
#   Decoder - Encoder delta: +1.83 W (paper reports decoder >> encoder, e.g. ~20W vs ~2W)
#
# [2/2] Running CNN model for 60.0s ...
#   Samples collected: 10566
#   CNN mean power: 73.62 W, std: 3.49 W (paper reports a steady ~constant trace)
#
# Saved plot to figure1_validation.png
# Figure(1200x400)
# ...

# %%
import os

print(os.path.exists("figure1_validation.png"))
# Out:
# True

# %%
from PIL import Image
from IPython.display import display

display(Image.open("figure1_validation.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x600>

# %%
import sys
import torch

print("Python executable:", sys.executable)
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python executable: C:\Users\ANIKET\anaconda3\python.exe
# Torch version: 2.11.0+cu128
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
# %run validate_figure2a.py --duration 10
# Out:
# Using device: NVIDIA GeForce RTX 3050 Laptop GPU
#
# Measuring idle GPU power baseline (3s)...
#   Idle power: 15.55 W
#
# [1/2] Running custom Transformer (1 enc / 1 dec layer, 8 heads, d_model=512, seq_len=512, decode_len=512, batch=128) for 10.0s ...
# C:\Users\ANIKET\anaconda3\Lib\site-packages\torch\nn\modules\transformer.py:144: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   self.encoder = TransformerEncoder(
# Encoder duration: 233621.18 ms
# Decoder duration: 2685700.21 ms
#   Samples collected: 520881
#   Mean power - Encoder phase: 48.84 W (delta vs idle: +33.29 W)
#   Mean power - Decoder phase: 52.09 W (delta vs idle: +36.54 W)
#   Decoder - Encoder delta: +3.26 W (paper reports decoder >> encoder, e.g. ~20W vs ~2W)
#
# [2/2] Running CNN model for 10.0s ...
#   Samples collected: 1796
# ...

# %%
# %run validate_figure2a.py --duration 10 --seq-len 256 --decode-len 256 --batch-size 64
# Out:
# Using device: NVIDIA GeForce RTX 3050 Laptop GPU
#
# Measuring idle GPU power baseline (3s)...
#   Idle power: 18.89 W
#
# [1/2] Running custom Transformer (1 enc / 1 dec layer, 8 heads, d_model=512, seq_len=256, decode_len=256, batch=64) for 10.0s ...
# Encoder duration: 15506.35 ms
# Decoder duration: 160764.87 ms
#   Samples collected: 31189
#   Mean power - Encoder phase: 62.36 W (delta vs idle: +43.47 W)
#   Mean power - Decoder phase: 60.13 W (delta vs idle: +41.24 W)
#   Decoder - Encoder delta: -2.23 W (paper reports decoder >> encoder, e.g. ~20W vs ~2W)
#
# [2/2] Running CNN model for 10.0s ...
#   Samples collected: 1784
#   CNN mean power: 72.97 W, std: 3.61 W (paper reports a steady ~constant trace)
#
# Saved plot to figure2a_3layer.png

# %%
# !dir validate_figure2b.py
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3692-ABE0
#
#  Directory of C:\Users\ANIKET\OneDrive\Desktop\GPU
#
# 06/26/2026  06:29 PM            14,410 validate_figure2b.py
#                1 File(s)         14,410 bytes
#                0 Dir(s)  107,435,433,984 bytes free

# %%
import torch

print("CUDA Available :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU :", torch.cuda.get_device_name(0))
# Out:
# CUDA Available : True
# GPU : NVIDIA GeForce RTX 3050 Laptop GPU

# %%
from PIL import Image
from IPython.display import display

display(Image.open("figure2b_5layer.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x600>

# %%
# %run validate_figure2b.py --duration 10 --seq-len 256 --decode-len 256 --batch-size 64
# Out:
# Using device: NVIDIA GeForce RTX 3050 Laptop GPU
#
# Measuring idle GPU power baseline (3s)...
#   Idle power: 17.52 W
#
# [1/2] Running custom Transformer (1 enc / 1 dec layer, 8 heads, d_model=512, seq_len=256, decode_len=256, batch=64) for 10.0s ...
# Encoder duration: 3654.40 ms
# Decoder duration: 37890.00 ms
#   Samples collected: 7775
#   Mean power - Encoder phase: 74.09 W (delta vs idle: +56.56 W)
#   Mean power - Decoder phase: 74.74 W (delta vs idle: +57.22 W)
#   Decoder - Encoder delta: +0.66 W (paper reports decoder >> encoder, e.g. ~20W vs ~2W)
#
# [2/2] Running CNN model for 10.0s ...
#   Samples collected: 1856
#   CNN mean power: 74.65 W, std: 0.60 W (paper reports a steady ~constant trace)
#
# Saved plot to figure2b_5layer.png

# %%
# %run validate_figure2b.py --duration 60 --seq-len 256 --decode-len 256 --batch-size 64
# Out:
# Using device: NVIDIA GeForce RTX 3050 Laptop GPU
# CUDA Capability: (8, 6)
#
# Measuring idle GPU power baseline (3s)...
#   Sampling idle power...
#   Idle power: 16.49 W
#
# [1/2] Running custom Transformer (8 enc / 8 dec layers, 8 heads, d_model=512, seq_len=256, decode_len=256, batch=64) for 60.0s ...
#   Transformer total parameters: 69,234,960
#
#   Performing warm-up (3 iterations)...
#     Warm-up iteration 1/3 completed
#     Warm-up iteration 2/3 completed
#     Warm-up iteration 3/3 completed
#
#   Iteration 1:
#     Encoder duration: 5805.94 ms
#     Decoder duration: 60011.52 ms
#
#   Samples collected: 12243
#   Mean power - Encoder phase: 74.68 W (delta vs idle: +58.18 W)
#   Mean power - Decoder phase: 74.77 W (delta vs idle: +58.28 W)
#   Decoder - Encoder delta: +0.10 W
#
# [2/2] Running CNN model for 60.0s ...
#   CNN total parameters: 2,193,226
#
#   CNN iteration 100 (elapsed: 0.4s)
#   CNN iteration 200 (elapsed: 0.7s)
#   CNN iteration 300 (elapsed: 1.1s)
# ...

# %%
# %run validate_figure2b_5layer.py --duration 60 --seq-len 256 --decode-len 256 --batch-size 64
# Out:
# Using device: NVIDIA GeForce RTX 3050 Laptop GPU
# CUDA Capability: (8, 6)
#
# Measuring idle GPU power baseline (3s)...
#   Sampling idle power...
#   Idle power: 14.13 W
#
# [1/2] Running custom Transformer (5 enc / 5 dec layers, 8 heads, d_model=512, seq_len=256, decode_len=256, batch=64) for 60.0s ...
#   Transformer total parameters: 47,165,712
#
#   Performing warm-up (3 iterations)...
#     Warm-up iteration 1/3 completed
#     Warm-up iteration 2/3 completed
#     Warm-up iteration 3/3 completed
#
#   Iteration 1:
#     Encoder duration: 8199.14 ms
#     Decoder duration: 83087.68 ms
#
#   Samples collected: 16822
#   Mean power - Encoder phase: 28.43 W (delta vs idle: +14.30 W)
#   Mean power - Decoder phase: 27.86 W (delta vs idle: +13.73 W)
#   Decoder - Encoder delta: -0.57 W
#
# [2/2] Running CNN model for 60.0s ...
#   CNN total parameters: 2,193,226
#
#   CNN iteration 100 (elapsed: 0.8s)
#   CNN iteration 200 (elapsed: 1.8s)
#   CNN iteration 300 (elapsed: 2.3s)
# ...

# %%
# %run validate_3layers.py --duration 60 --seq-len 256 --decode-len 256 --batch-size 64
# Out:
# Using device: NVIDIA GeForce RTX 3050 Laptop GPU
# CUDA Capability: (8, 6)
#
# Measuring idle GPU power baseline (3s)...
#   Sampling idle power...
#   Idle power: 16.44 W
#
# [1/2] Running custom Transformer (3 enc / 3 dec layers, 8 heads, d_model=512, seq_len=256, decode_len=256, batch=64) for 60.0s ...
# C:\Users\ANIKET\anaconda3\Lib\site-packages\torch\nn\modules\transformer.py:144: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   self.encoder = TransformerEncoder(
#   Transformer total parameters: 32,452,880
#
#   Performing warm-up (3 iterations)...
#     Warm-up iteration 1/3 completed
#     Warm-up iteration 2/3 completed
#     Warm-up iteration 3/3 completed
#
#   Iteration 1:
#     Encoder duration: 2178.85 ms
#     Decoder duration: 22891.60 ms
#
#   Iteration 2:
#     Encoder duration: 2249.98 ms
#     Decoder duration: 22941.37 ms
# ...
